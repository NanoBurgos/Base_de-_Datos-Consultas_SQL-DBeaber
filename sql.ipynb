# %% [markdown]
# # **Hay varias bases de datos ficticias o de ejemplo que puedes usar para practicar SQL con DBeaver.**
#
# 1. # Sakila
#
# Descripción: Base de datos de ejemplo creada por MySQL, representa un videoclub con tablas como actor, film, customer, rental.
#
# Ideal para: Practicar joins, agregaciones, subconsultas y manejo de fechas.
#
# Descarga:
# https://dev.mysql.com/doc/sakila/en/
#
# Cómo usarla en DBeaver:
#
# Descarga el archivo SQL.
#
# Crea una base de datos vacía en tu servidor local (MySQL o MariaDB).
#
# Importa el script SQL en DBeaver (Right-click → Tools → Execute Script).
#
# 2. # Northwind
#
# Descripción: Base de datos de ejemplo de Microsoft, sobre una empresa de ventas. Tablas típicas: Customers, Orders, Products.
#
# Ideal para: Practicar joins, GROUP BY, funciones agregadas y subconsultas.
#
# Descarga:
#
# Para MySQL: https://github.com/pthom/northwind_mysql
#
# Para SQLite: https://github.com/jpwhite3/northwind-SQLite3
#
# Uso en DBeaver: Igual que Sakila, solo importar el script.
#
# 3. # Chinook
#
# Descripción: Base de datos sobre una tienda de música digital, con tablas como Album, Artist, Invoice, Customer.
#
# Ideal para: Consultas sobre joins, agregaciones, análisis de ventas.
#
# Descarga: https://github.com/lerocha/chinook-database
#
# 4. # Pagila
#
# Descripción: Versión de Sakila adaptada para PostgreSQL.
#
# Ideal para: Si quieres practicar en PostgreSQL específicamente.
#
# Descarga: https://github.com/devrimgunduz/pagila
#
# 5. # Bases de datos SQLite de ejemplo
#
# Muchos recursos en GitHub tienen bases listas en formato .sqlite que DBeaver puede abrir directamente sin instalar nada.
#
# Ejemplo: Chinook SQLite https://github.com/lerocha/chinook-database
#
# # 💡 Tip: Si quieres empezar rápido en DBeaver:
#
# Descarga una base en SQLite (Chinook o Northwind SQLite).
#
# En DBeaver: Database → New Database Connection → SQLite → File.
#
# ¡Ya puedes practicar sin instalar nada más!

# %% [markdown]
# # Que son las bases de datos?
#
# Las bases de datos son sistemas organizados para almacenar, gestionar y recuperar información de manera eficiente.
#
# Son como una versión mucho más avanzada y poderosa de una hoja de cálculo, diseñadas para manejar grandes volúmenes de datos de forma rápida, segura y ordenada.

# %% [markdown]
# # Definición simple
#
# Una base de datos (DB) es un conjunto de datos organizados, guardados en una computadora, al cual podés acceder, modificar o consultar mediante un sistema gestor de bases de datos (DBMS) como MySQL, PostgreSQL, SQLite, SQL Server, etc.

# %% [markdown]
# # ¿Qué tipo de datos guardan?
#
# Prácticamente cualquier cosa:
#
# - Usuarios registrados
#
# - Productos
#
# - Ventas
#
# - Libros
#
# - Sensores IoT
#
# - Logs
#
# Cualquier información estructurada

# %% [markdown]
# # Componentes clave
#
# **Tablas** → como hojas de Excel
#
# **Filas** = registros
#
# **Columnas** = campos
#
# **Relaciones** → cómo se conectan las tablas entre sí
#
# **Consultas (SQL)** → instrucciones para pedir o modificar datos
#
# Ej: SELECT, INSERT, UPDATE, DELETE
#
# **Índices** → para buscar más rápido

# %% [markdown]
# # Tipos de bases de datos
# 🔹 **Relacionales (SQL)**
#
# Las más comunes. Usan tablas y relaciones.
# Ejemplos: MySQL, PostgreSQL, SQLite, SQL Server.
#
# 🔹 **NoSQL**
#
# Más flexibles, no usan tablas.
# Ejemplos: MongoDB (documentos), Redis (clave-valor).

# %% [markdown]
# # ¿Para qué sirven?
#
# - Guardar datos de forma persistente
#
# - Evitar duplicados
#
# - Consultar grandes volúmenes de información rápidamente
#
# - Mantener datos seguros
#
# - Compartir datos entre múltiples usuarios o sistemas
#
# - Conectar aplicaciones webs, móviles, IoT, etc.

# %% [markdown]
# Una base de datos de una librería podría tener:
#
# **Tabla libros**
#
# | id	| titulo | precio |	stock |
# |:-:|:-:|:-:|:-:|
# | 1 |	La Odisea |	50 |	3 |
# | 2 |	Harry Potter |	80 |	10 |
#
# **Tabla categorias**
#
# |id |	nombre |
# |:-:|:-:|
# |1 |	Fantasía |
# |2 |	Historia |

# %% [markdown]
# Luego podrías hacer una consulta SQL como:
#
# SELECT titulo, precio
# FROM libros
# WHERE precio > 60;

# %% [markdown]
# # **Que quiere decir SQL?**
#
# SQL significa **Structured Query Language**, que en español es:
#
# Lenguaje de Consulta Estructurado
#
# Es un lenguaje que se usa para interactuar con bases de datos relacionales.

# %% [markdown]
# # **Para qué sirve el SQL?**
#
# **SQL te permite:**
#
# - Consultar datos (SELECT)
#
# - Insertar datos nuevos (INSERT)
#
# - Modificar datos existentes (UPDATE)
#
# - Eliminar datos (DELETE)
#
# - Crear tablas y bases nuevas (CREATE)
#
# - Definir relaciones entre tablas (FOREIGN KEY)
#
# - Proteger y optimizar la base de datos

# %% [markdown]
# Todo eso usando comandos escritos en texto.
#
# **Ejemplo en 1 línea:**
#
#             SELECT * FROM usuarios;
#
#
# **Significa:** "Mostrame todos los datos de la tabla usuarios".

# %% [markdown]
# # ¿Por qué se llama “estructurado”?
#
# Porque el lenguaje trabaja sobre datos organizados en tablas, con filas y columnas. No es un lenguaje desordenado; tiene reglas claras y estructuras definidas.

# %% [markdown]
# # **Importante:**
#
# SQL **no es un gestor de base de datos**, sino el lenguaje que usan los gestores como:
#
# - MySQL
#
# - PostgreSQL
#
# - SQLite
#
# - SQL Server
#
# - MariaDB

# %% [markdown]
# # **Lista simple de los comandos SQL básicos, con explicación y ejemplo para cada uno.**

# %% [markdown]
# # 📌 **1. SELECT — Consultar datos**
#
# Sirve para leer información de una tabla.
#
# **Explicación:**
#
# Pide datos y los muestra como un resultado.
#
# **Ejemplo:**
#
#             SELECT titulo, precio
#
#             FROM libros;
#
#
# Trae las columnas titulo y precio de la tabla libros.

# %% [markdown]
# # 📌 **2. WHERE — Filtrar resultados**
#
# Se usa para aplicar condiciones.
#
# **Explicación:**
#
# Selecciona solo las filas que cumplen cierta regla.
#
# **Ejemplo:**
#
#             SELECT *
#
#             FROM libros
#
#             WHERE precio > 50;
#
#
# Trae solo los libros cuyo precio es mayor a 50.

# %% [markdown]
# # 📌 **3. INSERT — Insertar datos**
#
# Agrega un nuevo registro.
#
# **Explicación:**
#
# Inserta una fila dentro de una tabla.
#
# **Ejemplo:**
#
#         INSERT INTO libros (titulo, precio, stock)
#
#         VALUES ('El Hobbit', 80, 10);
#
#
# Agrega un libro nuevo en la tabla.

# %% [markdown]
# # 📌 **4. UPDATE — Modificar datos**
#
# Cambia valores existentes.
#
# **Explicación:**
#
# Actualiza una o varias filas.
#
# **Ejemplo:**
#
#         UPDATE libros
#
#         SET precio = 100
#
#         WHERE titulo = 'El Hobbit';
#
#
# Modifica el precio del libro “El Hobbit”.

# %% [markdown]
# # 📌 **5. DELETE — Borrar datos**
#
# Elimina filas.
#
# **Explicación:**
#
# Borra registros. (⚠️ se debe usar con WHERE)
#
# **Ejemplo:**
#
#         DELETE FROM libros
#
#         WHERE titulo = 'El Hobbit';
#
#
# Elimina el libro “El Hobbit”.

# %% [markdown]
# # 📌 **6. CREATE TABLE — Crear una tabla**
#
# Define una tabla nueva con columnas.
#
# **Explicación:**
#
# Estructura donde se guardarán datos.
#
# **Ejemplo:**
#
#         CREATE TABLE categorias (
#
#             id INT PRIMARY KEY,
#
#             nombre VARCHAR(100)
#
#         );
#
#
# Crea una tabla de categorías.

# %% [markdown]
# # 📌 **7. ALTER TABLE — Modificar una tabla**
#
# Permite agregar o cambiar columnas.
#
# **Explicación:**
#
# Ajusta la estructura de la tabla.
#
# **Ejemplo:**
#
#         ALTER TABLE libros
#
#         ADD COLUMN autor VARCHAR(100);
#
#
# Agrega la columna “autor” a la tabla libros.

# %% [markdown]
# # 📌 **8. DROP TABLE — Borrar una tabla**
#
# Elimina totalmente la tabla.
#
# ⚠️ Cuidado: se pierde todo.
# **Ejemplo:**
#
#         DROP TABLE categorias;

# %% [markdown]
# # 📌 **9. ORDER BY — Ordenar resultados**
#
# Ordena por una columna específica.
#
# **Explicación:**
#
# Ascendente (ASC) o descendente (DESC).
#
# **Ejemplo:**
#
#         SELECT titulo, precio
#
#         FROM libros
#
#         ORDER BY precio DESC;
#
#
# Ordena los libros del más caro al más barato.

# %% [markdown]
# # 📌 **10. LIMIT — Limitar cantidad de filas**
#
# Sirve para mostrar solo un número de resultados.
#
# **Ejemplo:**
#
#         SELECT *
#
#         FROM libros
#
#         LIMIT 5;
#
#
# Trae solo los primeros 5 libros.

# %% [markdown]
# # 📌 **11. JOIN — Unir tablas**
#
# Permite combinar datos de múltiples tablas relacionadas.
#
# **Explicación:**
#
# Muy usado cuando las tablas están conectadas por claves foráneas.
#
# **Ejemplo:**
#
#         SELECT l.titulo, c.nombre AS categoria
#
#         FROM libros l
#
#         JOIN categorias c ON l.categoria_id = c.id;
#
#
# Une la tabla libros con categorias.

# %% [markdown]
# # **Doble JOIN**
#
# Es simplemente cuando en una misma consulta SQL unís más de dos tablas al mismo tiempo.
#
# No existe un comando especial llamado así: es solo hacer JOIN + JOIN en cadena.
#
# **Por qué se usa?**
#
# Porque muchas veces la información está distribuida en varias tablas.
#
# **Ejemplo típico:**
#
# - libros
#
# - categorias
#
# - autores
#
# Si quiero traer datos del libro + su categoría + su autor, necesitás 3 tablas, entonces hacemos 2 JOINs.

# %% [markdown]
# # **Ejemplo claro de doble JOIN**
#
# Supongamos estas tablas:
#
# 📘 libros
#
# | id | titulo | categoria_id | autor_id |
#
# 🏷️ categorias
#
# | id | nombre |
#
# ✍ autores
#
# | id | nombre |

# %% [markdown]
# **Consulta con doble JOIN:**
#
#         SELECT l.titulo,
#
#             c.nombre AS categoria,
#
#             a.nombre AS autor
#
#         FROM libros l
#
#         JOIN categorias c ON l.categoria_id = c.id
#
#         JOIN autores a ON l.autor_id = a.id;

# %% [markdown]
# # **¿Qué pasa aquí?**
#
# **Primer JOIN:**
#
# JOIN categorias c ON l.categoria_id = c.id
#
# → Une cada libro con su categoría.
#
# **Segundo JOIN:**
#
# JOIN autores a ON l.autor_id = a.id
#
# → Une cada libro con su autor.
#
# 📌 Resultado: una tabla combinada con datos de 3 tablas distintas.

# %% [markdown]
# # **CONSULTAS SQL (A | B | M | L)**
#
# Las consultas SQL son los "dialogos" o "preguntas" que se generan entre el usuario y el sistema gestor de bases de datos donde se encuentran almacenados ciertos datos
#
# # **De Lectura**
#
# - **SELECT**: Sentencia utulizada para especificar a que atributo (dato) se pretende acceder
#
# - **FROM**: se utiliza con SELECT, para especificar desde que tabla (entidad) se pretende traer el dato
#
# - **WHERE**: Sentencia para proponer la condicion especifica que debe cumplir el dato que se pretende traer (no es una sentencia obligatoria)
#
# # **De Escritura** (Alta)
#
# - **INSERT INTO**: Es utulizada para especificar en que tabla se pretende insertar un dato
#
# - **VALUES**: Se utiliza en conjunto con INSERT INTO para especificar que valores iran en la tabla
# Los valores siempre van entre parentesis separados por coma (,) y en caso de que sea string se pone entre comillas
#
# # **De Modificacion**
#
# - **UPDATE**: Es utilizada para especificar en que tabla se pretende modificar un dato
#
# - **SET**: Se utiliza en conjunto con UPDATE para especificar cual sera el nuevo valor/dato
#
# - **WHERE**: Sentencia para proponer la condicion especifica que debe cumplir el dato de referencia del registro que se pretende modificar (No es una sentencia obligatoria, pero si recomendada)
#
# # **De Baja**
#
# - **DELETE FROM**: Es utilizada para modificar un registro de una tabla de forma permanente
#
# - **WHERE**: Sentencia para proponer la condicion especifica que debe cumplir el dato de referencia del registro que se pretende dar de baja (No es una sentencia obligatoria pero si recomendada)

# %% [markdown]
# # **ORDER y GROUP BY** (De Orden y/o Agrupamiento)
#
# **SE USAN EN CONJUNTO CON EL SELECT**
#
# - **ORDER BY**: Es utilizada para especificar por que criterio se pretende ordenar los registros de una tabla
#
# Con ORDER BY tambien se usa ASC Y DESC para ordenar de forma ascendente o descendente
#
#             SELECT *
#             FROM empleado
#             ORDER BY apellido ASC
#
# En esta consulta, traemos todos los datos de la tabla empleados, y ordenamos teniendo en cuenta el apellido en orden ascendente (a->z)
#
# - **GROUP BY**: Es utilizada para especificar por que criterio se puede agrupar los registros de una tabla
#
#             SELECT cargo
#             FROM empleado
#             GROUP BY cargo
#
# En esta consulta si hay varios empleados con el mismo puesto/cargo, solo se mostrara un cargo respectivo

# %% [markdown]
# # **FUNCIONES COMPLEMENTARIAS**
#
# - **COUNT**
#
#             SELECT COUNT(cod_prod) FROM productos
#
# (cod_prod es la primary key de esa tabla)
#
# **Consulta**: Seleccioname contando todos los productos de la tabla productos
#
# Esto no devolvera los registros, sino que devolvera la cantidad de registros que tengo
#
# - **MIN y MAX**
#
#             SELECT MAX(precio) FROM productos
#
# **Consulta**: traeme el precio maximo de la tabla productos
#
# Esto devulve el Precio mas grande registrado
#
#             SELECT MIN(precio) FROM productos
#
# **Consulta**: traeme el precio minimo de la tabla productos
#
# Esto devulve el Precio mas chico registrado
#
# - **AVG** (Average) : calcula el promedio
#
# - **SUM**: Suma valores (numericos)

# %% [markdown]
# **EJERCICIO**
#
# 1- Calcular un promedio de valores dentro de una tabla
#
# **Ej**:el promedio de precios en la tabla productos
#
#             SELECT AVG(precios) FROM productos
#
# 2- Calcular la cant total de productos en la tabla productos
#
# **Ej**: calcular el total de productos de una tienda
#
#             SELECT SUM(stock) FROM productos
#
# (stock seria la columna en donde cada producto marca su stock o existencia correspondiente)
#
# # **A estas consultas tambien se pueden aplicar condiciones y/o filtros**
#
# **Ej**: Calcular el total de productos en stock de la marca XIAOMI
#
#             SELECT SUM(stock) FROM productos
#             WHERE marca = "XIAOMI"

# %% [markdown]
# # **JOIN, LEFT JOIN, RIGTH JOIN Y FULL JOIN**
#
# **INNER JOIN** = JOIN Normal (INTERSECCION)
# (Se utiliza en conjunto con el SELECT)
#
# INNER JOIN busca unir dos tablas por algun dato que tengan en comun
#
# 1. Forma Implicita(Estamos ocultando el INNER JOIN, estamos usandolo indirectamente)
#
#             SELECT *
#             FROM empleados, departamento
#             WHERE empleado.id_departamento = departamento.id_departamento
#
# No se escribe el INNER JOIN, en FROM, ya se escriben las tablas que seran utilizadas
#
# 2. Forma Explicita (Decimos que vamos a usar el INNER JOIN)
#
#             SELECT *
#             FROM empleados
#             INNER JOIN departamento
#             ON empleado.id_departamento = departamento.id_departamento
#
# con ON especificamos que dato de una tabla, coincide con el dato de otra tabla

# %% [markdown]
# # **LEFT JOIN**
# Muestra el conjunto completo de los registros de la tabla A, con los registros que coincidan de la tabla B (si es que los hay)
#
# ![image.png](attachment:image.png)
#
# **Ej:**
#
#             SELECT *
#
#             FROM empleado
#
#             LEFT JOIN departamento
#
#             ON empleado.id_departamento = departamento.id_departamento
#
# Traeme todo de empleado, uniendo por izquierda con departamento donde coincidan las id departamento

# %% [markdown]
# # **RIGHT JOIN**
# Es el reflejo del Left Join. Muestra el conjunto completo de los registros de la tabla B, con los registros que coincidan de la tabla A (si es que los hay)
#
# ![image.png](attachment:image.png)
#
# **Ej:**
#
#             SELECT *
#
#             FROM empleado
#
#             RIGHT JOIN departamento
#
#             ON empleado.id_departamento = departamento.id_departamento

# %% [markdown]
# # **INNER JOIN**
#
# INNER JOIN devuelve solo las filas que tienen coincidencias en ambas tablas según la condición de unión.
#
# Es decir, muestra la intersección: datos que existen en la tabla A y en la tabla B.

# %% [markdown]
# # **OUTER JOIN**
#
# OUTER JOIN muestra todas las filas de una tabla aunque no exista coincidencia en la otra. Puede completarse con NULL en los datos que no coinciden.
#
# Existen 3 tipos:
#
# **a) LEFT OUTER JOIN**
#
# Devuelve todas las filas de la tabla izquierda y las coincidencias de la derecha.
# Si no hay coincidencia, la parte derecha queda en NULL.
#
# **b) RIGHT OUTER JOIN**
#
# Devuelve todas las filas de la tabla derecha y las coincidencias con la izquierda.
# Si no coincide, la parte izquierda queda NULL.
#
# **c) FULL OUTER JOIN**
#
# Devuelve todas las filas de ambas tablas, coincidan o no.
# Donde no coinciden, completa con NULL.

# %% [markdown]
# # **RESUMEN VISUAL**
#
# |Tipo de JOIN |	Qué devuelve|
# | :-: | :-: |
# |INNER JOIN	| Solo coincidencias entre ambas tablas|
# |LEFT JOIN	| Todo de la tabla izquierda + coincidencias|
# |RIGHT JOIN	| Todo de la tabla derecha + coincidencias |
# |FULL OUTER JOIN |	Todo de ambas tablas |

# %% [markdown]
# # **SUB-CONSULTAS**
#
# **¿Que son las subconsultas?**
#
# Es una consulta SQL que se puede encontrar dentro de otra consulta SQL
#
# Dentro de una sola sentencia SQL, se pueden especificar hasta **16 subconsultas** y dentro de una subconsulta se pueden especificar otras subconsultas
#
# Las subconsultas se ejecutan **de la ultima a la primera** dentro de la **sentencia SQL principal** en la que
#
# **Ej1:**
#
#             SELECT *
#
#             FROM empleadps
#
#             WHERE sueldo >=
#
#                 (SELECT AVG(sueldo)
#
#                 FROM empleados)
#
#
# **Ej2:**
#
#             SELECT *
#
#             FROM hinchas
#
#             WHERE equipo_futbol IN
#
#                 (SELECT nombre_equipo
#
#                 FROM equipos_primera)
#
#
# Para este ejemplo:
#
# hinchas es una tabla en donde figuran los nombres de los hinchas y el eqiupo al que apoyan
#
# nombre_equipo es una tabla en la que estan todos los nombres de los equipos. 1era, 2da division etc.
#
# equipos_primera es otra tabla en donde solo figuran los equipos de 1era division
#
# La subconsulta esta realizando consulta sobre otra tabla de nuestra base de datos

# %% [markdown]
# ![image.png](attachment:image.png)
